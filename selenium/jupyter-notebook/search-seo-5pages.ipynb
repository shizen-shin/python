# %% [markdown]
# 5ページ目までのタイトルを取得

# %%
from selenium import webdriver
browser = webdriver.Chrome('chromedriver.exe')

# Chromeの検索結果「hello」を開く
browser.get('https://www.google.com/search?q=hello&rlz=1C1SQJL_jaJP784JP784&oq=hello&aqs=chrome..69i57.2534j0j1&sourceid=chrome&ie=UTF-8')
elem_search = browser.find_element_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[2]/div/div[2]/input')
elem_search.clear()

# 指定したKWを検索（ここではSEO）
elem_search.send_keys('SEO')
elem_next = browser.find_element_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[2]/button').click()


#5ページ目までの自然検索タイトル一覧を取得
titles =[]

def extractTitle():

    elems_title= browser.find_elements_by_class_name('LC20lb')
    for elem_title in elems_title:
        title = elem_title.text
        titles.append(title)

    next = browser.find_element_by_xpath('//*[@id="pnnext"]/span[2]').click()

for _ in range(5):
    extractTitle()

# %%
#順位を取得
ranks = []

for i in range(1,len(titles)+1):
    rank = int(i)
    ranks.append(rank)

# %%
import pandas as pd
df = pd.DataFrame()

df['rank']=ranks
df['title']=titles

  #downloadフォルダに出力
df.to_csv("~/Downloads/search_SEO_titles.csv",index = False,encoding = "utf_8_sig")

# %%
df
# Out:
#     rank                                              title
# 0      1                           SEOとは？SEOの基礎知識について｜SEOラボ
# 1      2                  SEO対策とは？SEO対策で上位表示するための方法について ...
# 2      3                              検索エンジン最適化 - Wikipedia
# 3      4            SEOとは？ 押さえておくべき24のSEO対策方法とポイント - Gyro-n
# 4      5        SEO とは 意味/解説/説明 （エスイーオー） 【Search Engine ...
# 5      6                  新人に読ませておきたい「グーグルSEOでやったら本当にヤバいこと」
# 6      7              SEOとは？SEOで成果を出すための基本的な考え方 | SEO基礎 ...
# 7      8               SEO対策とは?初心者でも簡単にできるSEOの基礎と基本を学ぼう ...
# 8      9             【2020年最新版】SEOとは？初心者向け完全ガイド - Marketing
# 9     10              SEOとは? 定義・目的・方法まで徹底解説!【Web担当者さま必読 ...
# 10    11               SEOの基本とは？上位表示するための対策ができるSEO Pack ...
# 11    12                         SEOTOOLS - SEO対策を無料ツールで診断！
# 12    13                 SEO（検索エンジン最適化）とは？ 概念から対策方法のまとめ ...
# 13    14  SEO が必要なケース - Search Console ヘルプ - Google Support
# 14    15       検索エンジン最適化（SEO）スターター ガイド - Search Console ...
# 15    16                    SEOで成果を出すために必要な知識と実践方法の全て - バズ部
# 16    17                         SEOとは？ - HP初心者むけ基本のSEO対策方法
# 17    18               Google上位20のサイトと自サイトの内部要因を比較するツール ...
# 18    19                   SEOとは？基本から最新動向まで、SEO対策の全て - ウェブ部
# 19    20                             SEOとは - IT用語辞典 e-Words
# 20    21                          SEOとはそもそも何？【前編】 | クロスウォーク
# 21    22                              使えるSEOツール【ohotuku.jp】
# 22    23                        SEO対策 | PINTO! - 株式会社PLAN-B
# 23    24                【SEO対策】トップページの順位にこだわる会社はなぜ集客に失敗 ...
# 24    25                                     SEO対策｜株式会社ディーボ
# 25    26                    運営11年4,200社導入実績！SEO対策ならファイナルSEO
# 26    27             SEO Japan｜アイオイクスのWebサイト集客・CV改善サービス ...
# 27    28           キーワード検索数 チェックツール｜無料SEOツール aramakijake.jp
# 28    29                       SEOとは？基本と具体的な対策をわかりやすく解説 ...
# 29    30                    SEO対策の動画講義【SEO歴6年のノウハウを完全公開 ...
# 30    31              海外SEO情報ブログ - SuzukiKenichi.COM: 海外SEO
# 31    32                          SEO診断ツール itomakihitode.jp
# 32    33             SEO | マーケティング用語集 | シナジーマーケティング株式会社 ...
# 33    34            サイトSEO分析ツール：無料で診断 & 監査レポート - Neil Patel
# 34    35            SEO（検索エンジン最適化） | ホームページ制作 京都 ファンフェア ...
# 35    36                SEO対策の完全マップ【入門・基礎・中級・上級：16記事で解説 ...
# 36    37               SEO対策-サポート付きSEOで順位上昇を目指す｜SEO Manager
# 37    38                SEOとは何ですか？ | 京都のホームページ制作会社 株式会社 ...
# 38    39               SEO対策(検索エンジン最適化)とは？初心者にもわかりやすく解説 ...
# 39    40              SEO対策（検索エンジン最適化）とは？【2020年版 最新実践方法 ...
# 40    41                トレジャーSEO｜Google評価基準を教えるSEO総合チェックツール
# 41    42                 効果のあるSEO対策を提供SEOスタイル | 戦略的なSEO ...
# 42    43               売上を上げるSEO対策会社のジオコード｜13年で4,000サイト ...
# 43    44                      SEOコンサルティング｜インターネット広告代理店アイレップ
# 44    45                ロングテールSEO対策キーワードマッチ | 株式会社ブログウォッチャー
# 45    46                  SEO対策とは？順位上昇に必要な要点まとめ | キーワード ...
# 46    47                                    SEO - アユダンテ株式会社
# 47    48                SEO/コンテンツマーケティングツール | DemandMetrics
# 48    49           これだけやれば集客できる はじめてのSEO | 瀧内 賢 |本 | 通販 ...
